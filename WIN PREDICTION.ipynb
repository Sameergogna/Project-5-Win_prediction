# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df1 = pd.read_excel("D:/Download/Win_Prediction_Data.xlsx")

# %%
df = pd.read_excel("D:/Download/Win_Prediction_Data.xlsx")

# %%
df.shape
# Out:
# (10061, 9)

# %%
df1.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code
# 0  Gopa Trilochana 150000.000              Won
# 1  Gopa Trilochana 744705.880              Won
# 2   Russell Dahlen  60000.000             Lost
# 3   Russell Dahlen  60000.000             Lost
# 4   Russell Dahlen  80882.350             Lost

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10061 entries, 0 to 10060
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Client Category   9982 non-null   object
#  1   Solution Type     10061 non-null  object
#  2   Deal Date         10061 non-null  datetime64[ns]
#  3   Sector            10061 non-null  object
#  4   Location          10061 non-null  object
#  5   VP Name           10061 non-null  object
#  6   Manager Name      10061 non-null  object
#  7   Deal Cost         10061 non-null  float64
#  8   Deal Status Code  10061 non-null  object
#  9   year              10061 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 786.1+ KB

# %%
df['Client Category'].isnull().sum()
# Out:
# 79

# %%
df['Client Category'].value_counts()
# Out:
# Others                   1763
# Internal                 1454
# Services_based           1202
# Tech                      913
# Domestic Public Bank      419
# International Bank        376
# Consulting                352
# Finance                   339
# Telecom                   327
# Power ind                 264
# Domestic Private Bank     262
# Insurance                 247
# Consumer Good             185
# Automobiles               178
# Infrastructure            152
# Domestic Bank             134
# Retail_market             126
# Govt                      121
# Hospitality               119
# Manufacturing             117
# Pharma                    110
# Healthcare                 99
# Electronics                81
# Media_Journal              71
# Industries                 66
# Research Development       63
# Energy                     57
# Knowledge                  50
# Management                 43
# Govt Bank Special          41
# Payment                    40
# ...

# %%
df['year']=df['Deal Date'].dt.year

# %%
max_deal_year=df.groupby(['year','Client Category']).agg(count_of_deal=('Client Category','count'),
                                                           mean_of_deal=('Deal Cost','mean')).reset_index()
max_deal_year
# Out:
#      year        Client Category  count_of_deal  mean_of_deal
# 0    2011             Consulting              2    617647.055
# 1    2011          Consumer Good              3    379901.960
# 2    2011          Domestic Bank              1    588235.290
# 3    2011  Domestic Private Bank              2     66176.470
# 4    2011   Domestic Public Bank              2   2613823.530
# ..    ...                    ...            ...           ...
# 317  2019   Research Development              2    382352.940
# 318  2019          Retail_market              3    356862.747
# 319  2019         Services_based             29    542890.467
# 320  2019                   Tech             31    419079.697
# 321  2019                Telecom              3    568627.450
#
# [322 rows x 4 columns]

# %%
max_deal_year.sort_values(by='count_of_deal',ascending=False)
# Out:
#      year    Client Category  count_of_deal  mean_of_deal
# 272  2018           Internal            306   1636155.326
# 162  2015             Others            299    462791.659
# 280  2018             Others            298    693503.751
# 201  2016             Others            282    666563.413
# 241  2017             Others            272    897922.794
# ..    ...                ...            ...           ...
# 52   2012       Share_market              1    147058.820
# 53   2012          Tax_audit              1    397058.820
# 78   2013          Logistics              1     44117.650
# 76   2013  International Org              1    470588.240
# 249  2017       Share_market              1    147058.820
#
# [322 rows x 4 columns]

# %%
max_deal=df.groupby(['Client Category' ]).agg(sum_of_deal=('Deal Cost','max')).reset_index().sort_values(by = 'sum_of_deal',ascending = False)

# %%
max_deal.max()
# Out:
# Client Category     e-commerce
# sum_of_deal       36764705.880
# dtype: object

# %%
max_ind_deal = pd.DataFrame(df.groupby(["Client Category"])["Deal Cost"].sum().reset_index(name='deal_cost'))
max_ind_deal= max_ind_deal.sort_values('deal_cost', ascending=False)
max_ind_deal
# Out:
#           Client Category      deal_cost
# 19               Internal 1481759118.370
# 28                 Others 1089370589.020
# 35         Services_based  657495000.500
# 38                   Tech  556006765.180
# 39                Telecom  430811176.670
# 6    Domestic Public Bank  403643529.550
# 2              Consulting  370720294.280
# 20     International Bank  300861176.650
# 18              Insurance  290900294.280
# 31              Power ind  275611764.780
# 4           Domestic Bank  224152941.200
# 5   Domestic Private Bank  214348235.440
# 10                Finance  171241470.760
# 3           Consumer Good  136501176.520
# 1             Automobiles  114572353.090
# 17         Infrastructure  105689411.830
# 30                 Pharma   96374705.930
# 11                   Govt   95982352.930
# 25          Manufacturing   78900294.130
# 34          Retail_market   68634117.700
# 8                  Energy   66733235.330
# 7             Electronics   46015000.080
# ...

# %%
max_deal_year1=df.groupby(['Client Category']).agg(sum_of_deal=('Deal Cost','sum')).reset_index()

# %%
max_deal_year1.max()
# Out:
# Client Category       e-commerce
# sum_of_deal       1481759118.370
# dtype: object

# %%
df
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code  year
# 0          Ekta Zutshi  Gopa Trilochana  150000.000              Won  2012
# ...

# %%
pd.crosstab(df1["Client Category"],df1["Deal Status Code"]).sort_values(by= 'Won', ascending=False)
# Out:
# Deal Status Code       Lost  Won
# Client Category
# Internal                694  760
# Others                 1132  631
# Services_based          794  408
# Tech                    600  313
# Consulting              182  170
# International Bank      216  160
# Telecom                 192  135
# Power ind               152  112
# Finance                 230  109
# Domestic Public Bank    324   95
# Consumer Good            98   87
# Domestic Private Bank   176   86
# Insurance               178   69
# Automobiles             112   66
# Infrastructure           88   64
# Domestic Bank            78   56
# Manufacturing            80   37
# Govt                     86   35
# Pharma                   78   32
# Healthcare               68   31
# Media_Journal            42   29
# Electronics              54   27
# Hospitality              94   25
# Energy                   32   25
# Management               22   21
# Retail_market           106   20
# Industries               46   20
# ...

# %%
pd.crosstab(df['VP Name'],df['Deal Status Code']).sort_values(by = 'Won',ascending= False)
# Out:
# Deal Status Code     Lost  Won
# VP Name
# Long Bergstrom        450  471
# Mervin Harwood        794  372
# Sargar Deep Rao       610  346
# Ekta Zutshi           206  344
# Ankita Aggarwal       866  277
# Mangesh K. Singh      538  274
# neeraj kumar          254  217
# Rahul Bajpai          320  203
# Rosanna Maynez        484  178
# Hardeep Suksma        122   86
# som dutt              138   82
# Son Mcconnaughy       164   68
# Saurabh Singh         112   64
# Alam Syed              62   64
# Clinton Mani          124   60
# Molly Eakes            66   60
# Brendon Wycoff        132   57
# Rudraksh Sharma        90   57
# Jewell Tunstall       100   56
# Russell Dahlen         78   55
# Gopa Trilochana        84   52
# Gaurav Sameria         66   48
# Varsha Arora           60   44
# Vidur Hukle            58   42
# Gayle Molter           74   30
# Earline Langton        52   30
# Mayank Mewar           24   17
# Manpreet Singh         30   16
# Prashant Rawat         12   15
# ...

# %%
pd.crosstab(df['VP Name'],df['Deal Status Code'], normalize= 'index').sort_values(by = 'Won',ascending= False)
# Out:
# Deal Status Code     Lost   Won
# VP Name
# Ekta Zutshi         0.375 0.625
# Prashant Rawat      0.444 0.556
# Vikram Rawat        0.471 0.529
# Long Bergstrom      0.489 0.511
# Alam Syed           0.492 0.508
# Molly Eakes         0.524 0.476
# Lilli Storrs        0.538 0.462
# neeraj kumar        0.539 0.461
# Man Suddeth         0.552 0.448
# Jitendra Choudhary  0.571 0.429
# Varsha Arora        0.577 0.423
# Gaurav Sameria      0.579 0.421
# Vidur Hukle         0.580 0.420
# Mayank Mewar        0.585 0.415
# Russell Dahlen      0.586 0.414
# Hardeep Suksma      0.587 0.413
# Rahul Bajpai        0.612 0.388
# Rudraksh Sharma     0.612 0.388
# Gopa Trilochana     0.618 0.382
# Marcella Mo         0.625 0.375
# som dutt            0.627 0.373
# Earline Langton     0.634 0.366
# Saurabh Singh       0.636 0.364
# Sargar Deep Rao     0.638 0.362
# Jewell Tunstall     0.641 0.359
# Manpreet Singh      0.652 0.348
# Mangesh K. Singh    0.663 0.337
# Visvajeet Das       0.667 0.333
# ...

# %%
pd.crosstab(df['Manager Name'],df['Deal Status Code']).sort_values(by = 'Won', ascending= False)
# Out:
# Deal Status Code          Lost  Won
# Manager Name
# Molly Eakes                214  109
# Rudraksh Sharma            176   94
# Russell Dahlen              52   91
# Rayford Durgan              94   76
# Manpreet Singh             106   75
# ...                        ...  ...
# mayank chaudhary @ rahul     4    0
# Varun Bhel                   2    0
# Cameron Deleeuw              2    0
# Brenton Launius              2    0
# Laurine Quintanar            2    0
#
# [278 rows x 2 columns]

# %%
pd.crosstab(df['Manager Name'],df['Deal Status Code'], normalize = 'index').sort_values(by = 'Won', ascending= False).head(40)
# Out:
# Deal Status Code     Lost   Won
# Manager Name
# Aastha Gandhi       0.000 1.000
# Anish Jonson        0.000 1.000
# Vaibhav Somaskandan 0.000 1.000
# Uzaar Ali           0.000 1.000
# Upendra Bhatt       0.000 1.000
# Taran Singh         0.000 1.000
# Sumita Verma        0.000 1.000
# Sumit Arora         0.000 1.000
# Sultan Khan         0.000 1.000
# Arti Bindra         0.000 1.000
# Cleotilde Biron     0.000 1.000
# Rishab Jain         0.000 1.000
# Cori Gillispie      0.000 1.000
# Rishab Bhatt        0.000 1.000
# Ike Deppen          0.000 1.000
# Matt Redel          0.000 1.000
# Nanette Hennessee   0.000 1.000
# Rahul Singh         0.000 1.000
# Heath Mullarkey     0.000 1.000
# Ekta Zutshi         0.000 1.000
# Harshita Singh      0.000 1.000
# Natalia Dumlao      0.000 1.000
# Preston Dumire      0.000 1.000
# Preetan Gujar       0.000 1.000
# Prashant singh      0.000 1.000
# Palmer Holmberg     0.000 1.000
# Genny Mcgivney      0.000 1.000
# ...

# %%
df.head()
# Out:
#   Client Category Solution Type  Deal Date     Sector Location      VP Name  \
# 0         Telecom    Solution 7 2012-03-27  Sector 24       L5  Ekta Zutshi
# 1         Telecom    Solution 7 2012-09-25  Sector 24       L5  Ekta Zutshi
# 2        Internal   Solution 59 2011-08-01  Sector 20   Others  Ekta Zutshi
# 3        Internal   Solution 59 2011-04-28  Sector 20   Others  Ekta Zutshi
# 4        Internal   Solution 32 2011-06-03  Sector 20   Others  Ekta Zutshi
#
#       Manager Name  Deal Cost Deal Status Code  year
# 0  Gopa Trilochana 150000.000              Won  2012
# 1  Gopa Trilochana 744705.880              Won  2012
# 2   Russell Dahlen  60000.000             Lost  2011
# 3   Russell Dahlen  60000.000             Lost  2011
# 4   Russell Dahlen  80882.350             Lost  2011

# %%
max_solution = df.groupby(['Solution Type']).agg(sum_of_deal=('Deal Cost','sum')).reset_index()

# %%
max_solution.max()
# Out:
# Solution Type      Solution 9
# sum_of_deal     975672059.410
# dtype: object

# %%
mean_solution = df.groupby(['Solution Type']).agg(mean_of_deal=('Deal Cost','mean')).reset_index()

# %%
mean_solution.max()
# Out:
# Solution Type    Solution 9
# mean_of_deal    8272058.825
# dtype: object

# %%
year_sol_type= df.groupby(['year','Solution Type']).agg(count_of_deal=('Solution Type','count'),
                                                           mean_of_deal=('Deal Cost','mean'),sum_of_deal = ('Deal Cost','sum'), 
                                                        max_of_deal =('Deal Cost','max')).reset_index()

# %%
year_sol_type.sort_values(by='count_of_deal' , ascending=False )
# Out:
#      year Solution Type  count_of_deal  mean_of_deal   sum_of_deal  \
# 275  2018    Solution 9            316    839029.226 265133235.420
# 221  2018   Solution 10            288    855050.041 246254411.860
# 167  2016    Solution 9            259    716290.030 185519117.750
# 99   2015   Solution 32            253    597292.491 151115000.110
# 121  2015    Solution 9            249    470346.091 117116176.600
# ..    ...           ...            ...           ...           ...
# 26   2012   Solution 40              1    529411.770    529411.770
# 260  2018   Solution 50              1   1058823.530   1058823.530
# 264  2018   Solution 56              1    294117.650    294117.650
# 265  2018   Solution 57              1    323529.410    323529.410
# 229  2018   Solution 18              1    225000.000    225000.000
#
#      max_of_deal
# 275 13235294.120
# 221 27941176.470
# 167  8569411.770
# 99  14126470.590
# 121  5364705.880
# ..           ...
# 26    529411.770
# ...

# %%
year_sol_type.sort_values(by='mean_of_deal' , ascending=False )
# Out:
#      year Solution Type  count_of_deal  mean_of_deal  sum_of_deal  max_of_deal
# 259  2018    Solution 5              2  16176470.590 32352941.180 16176470.590
# 251  2018   Solution 41              2   8382352.940 16764705.880  8382352.940
# 161  2016   Solution 61              1   7965000.000  7965000.000  7965000.000
# 45   2013   Solution 36              3   6862745.100 20588235.300 10294117.650
# 73   2014   Solution 35              1   4911764.710  4911764.710  4911764.710
# ..    ...           ...            ...           ...          ...          ...
# 234  2018   Solution 24              1     81764.710    81764.710    81764.710
# 10   2011   Solution 39              8     64816.177   518529.420   176470.590
# 286  2019   Solution 28              1     58823.530    58823.530    58823.530
# 4    2011   Solution 29              1     58823.530    58823.530    58823.530
# 74   2014   Solution 36              1         0.000        0.000        0.000
#
# [306 rows x 6 columns]

# %%
year_sol_type.sort_values(by='sum_of_deal' , ascending=False )
# Out:
#      year Solution Type  count_of_deal  mean_of_deal   sum_of_deal  \
# 275  2018    Solution 9            316    839029.226 265133235.420
# 221  2018   Solution 10            288    855050.041 246254411.860
# 167  2016    Solution 9            259    716290.030 185519117.750
# 164  2016   Solution 67            138   1318365.303 181934411.820
# 241  2018   Solution 32            215    821564.980 176636470.680
# ..    ...           ...            ...           ...           ...
# 52   2013   Solution 55              1    102941.180    102941.180
# 234  2018   Solution 24              1     81764.710     81764.710
# 4    2011   Solution 29              1     58823.530     58823.530
# 286  2019   Solution 28              1     58823.530     58823.530
# 74   2014   Solution 36              1         0.000         0.000
#
#      max_of_deal
# 275 13235294.120
# 221 27941176.470
# 167  8569411.770
# 164 32352941.180
# 241 14000000.000
# ..           ...
# 52    102941.180
# ...

# %%
year_sol_type.sort_values(by='max_of_deal' , ascending=False )
# Out:
#      year Solution Type  count_of_deal  mean_of_deal   sum_of_deal  \
# 222  2018   Solution 11             62   2334316.889 144727647.130
# 164  2016   Solution 67            138   1318365.303 181934411.820
# 221  2018   Solution 10            288    855050.041 246254411.860
# 273  2018    Solution 7             72   1331997.549  95903823.560
# 185  2017   Solution 30             16   3837922.796  61406764.730
# ..    ...           ...            ...           ...           ...
# 282  2019    Solution 2              1    102941.180    102941.180
# 234  2018   Solution 24              1     81764.710     81764.710
# 4    2011   Solution 29              1     58823.530     58823.530
# 286  2019   Solution 28              1     58823.530     58823.530
# 74   2014   Solution 36              1         0.000         0.000
#
#      max_of_deal
# 222 36764705.880
# 164 32352941.180
# 221 27941176.470
# 273 25882352.940
# 185 25000000.000
# ..           ...
# 282   102941.180
# ...
